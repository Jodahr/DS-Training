# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
salary = pd.read_csv('/opt/hdp/share/data/workshop/Salaries.csv')

# %%
tips = pd.read_csv('/opt/hdp/share/data/workshop/tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# %matplotlib inline

# %%
tips.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff187ae3210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff185bab590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff185b30790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff185b22410>]], dtype=object)

# %%
sns.distplot(tips['total_bill'], kde=False)

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.boxplot(x='day', data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14745a1c571d> in <module>()
# ----> 1 sns.boxplot(x='day', data=tips)
#
# NameError: name 'sns' is not defined

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b9f1e2dc8f60> in <module>()
# ----> 1 sns.boxplot(x='day', y='total_bill', data=tips)
#
# NameError: name 'sns' is not defined

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True)

# %%
sns.pairplot(data=tips, hue='sex')
